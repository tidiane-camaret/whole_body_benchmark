# %%
from hydra import compose, initialize
from omegaconf import OmegaConf

with initialize(config_path="dev/whole_body_benchmark/configs"):
    cfg = compose(config_name="config")

print(OmegaConf.to_yaml(cfg))
# Out:
# /tmp/ipykernel_131791/912625114.py:4: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   with initialize(config_path="dev/whole_body_benchmark/configs"):
# paths:
#   nako_dir: /nfs/data/nii/data0/GNC/GNC_759
#   nnUNet_dir: /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/
#   results_dir: /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/results/

# %%
# create nnUNet_raw, nnUNet_preprocessed, nnUNet_results
import os
from pathlib import Path
import glob
dataset_name = "Dataset005_oppscreen_100"
img_base_path = Path(cfg.paths.nako_dir) / "links"
mask_base_path = Path(cfg.paths.nako_dir) / "data"
img_target = "30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii"
mask_target = "30/opportunistic-screening/seg.nii.gz"
os.makedirs(cfg.paths.nnUNet_dir + "/nnUNet_raw", exist_ok=True)
os.makedirs(cfg.paths.nnUNet_dir + "/nnUNet_preprocessed", exist_ok=True)
os.makedirs(cfg.paths.nnUNet_dir + "/nnUNet_results", exist_ok=True)

raw_ds_dir = os.path.join(cfg.paths.nnUNet_dir, f"nnUNet_raw/{dataset_name}")
os.makedirs(raw_ds_dir, exist_ok=True)
os.makedirs(os.path.join(raw_ds_dir, "imagesTr"), exist_ok=True)
os.makedirs(os.path.join(raw_ds_dir, "labelsTr"), exist_ok=True)
os.makedirs(os.path.join(raw_ds_dir, "imagesTs"), exist_ok=True)
os.makedirs(os.path.join(raw_ds_dir, "labelsTs"), exist_ok=True)

# %%
from pathlib import Path
import json
splits_path = Path(cfg.paths.results_dir) / 'splits.json'
with open(splits_path, 'r') as f:
    splits = json.load(f)

subjects_train, subjects_test = splits['train'], splits['test']

# %%
import nibabel as nib
import numpy as np
import shutil

def process_subject(subject, img_base_path, mask_base_path, img_target, mask_target, images_dir, labels_dir):
    img_path = img_base_path / subject / img_target
    mask_path = mask_base_path / subject / mask_target

    # --- Images: split 4D -> 4x 3D channel files ---
    print(f"Looking for images in: {img_path}")
    files = glob.glob(str(img_path))
    print(f"Subject: {subject}, Files found: {len(files)}")

    if len(files) > 0:
        img = nib.load(files[0])
        data = img.get_fdata()  # (320, 260, 316, 4)

        if data.ndim == 4:
            for ch in range(data.shape[-1]):
                channel_data = data[..., ch].astype(np.float32)
                new_img = nib.Nifti1Image(channel_data, img.affine, img.header)
                new_img.header.set_data_shape(channel_data.shape)
                dst = os.path.join(images_dir, f"{subject}_{ch:04d}.nii.gz")
                nib.save(new_img, dst)
                print(f"  Saved channel {ch} -> {dst}")
        else:
            # skip if not 4D
            print(f"  Warning: Image is not 4D, skipping: {files[0]}")

    # --- Mask: enforce 3D header and save ---
    print(f"Looking for masks in: {mask_path}")
    mask_files = glob.glob(str(mask_path))
    print(f"Subject: {subject}, Mask files found: {len(mask_files)}")

    if len(mask_files) > 0:
        mask = nib.load(mask_files[0])
        mask_data = mask.get_fdata().astype(np.uint8)

        # Squeeze out any phantom 4th dim
        if mask_data.ndim == 4:
            mask_data = mask_data[..., 0]

        new_mask = nib.Nifti1Image(mask_data, mask.affine, mask.header)
        new_mask.header.set_data_shape(mask_data.shape)
        dst = os.path.join(labels_dir, f"{subject}.nii.gz")
        nib.save(new_mask, dst)
        print(f"  Saved mask -> {dst}")


from concurrent.futures import ProcessPoolExecutor, as_completed

def run_parallel(subjects, images_dir, labels_dir, max_workers=16):
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        futures = {
            executor.submit(
                process_subject,
                subject,
                img_base_path, mask_base_path,
                img_target, mask_target,
                images_dir, labels_dir,
            ): subject
            for subject in subjects
        }
        for future in as_completed(futures):
            subject = futures[future]
            try:
                future.result()
            except Exception as e:
                print(f"ERROR processing {subject}: {e}")

run_parallel(subjects_train,
             os.path.join(raw_ds_dir, "imagesTr"),
             os.path.join(raw_ds_dir, "labelsTr"))

run_parallel(subjects_test,
             os.path.join(raw_ds_dir, "imagesTs"),
             os.path.join(raw_ds_dir, "labelsTs"))
# Out:
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100031/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100889/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100186/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100730/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100681/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100853/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100371/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100546/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100540/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100806/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100397/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100891/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100517/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100460/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100930/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100010/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100517, Files found: 1
# Subject: 100031, Files found: 1
# Subject: 100889, Files found: 1Subject: 100681, Files found: 1
# Subject: 100730, Files found: 1
#
# Subject: 100540, Files found: 1Subject: 100186, Files found: 1
#
# Subject: 100010, Files found: 1
# Subject: 100460, Files found: 1Subject: 100891, Files found: 1Subject: 100930, Files found: 1Subject: 100853, Files found: 1
#
#
#
# Subject: 100397, Files found: 1
# Subject: 100546, Files found: 1
# Subject: 100371, Files found: 1Subject: 100806, Files found: 1
#
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100517_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100540_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100540_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100517_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100540_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100517_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100540_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100540/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100517_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100517/30/opportunistic-screening/seg.nii.gz
# Subject: 100540, Mask files found: 1
# Subject: 100517, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100540.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100261/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100517.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100175/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100261, Files found: 1
# Subject: 100175, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100371_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100031_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100730_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100889_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100010_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100546_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100806_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100930_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100853_0000.nii.gz
#
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100681_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100891_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100186_0000.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100031_0001.nii.gz
#
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100371_0001.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100460_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100397_0000.nii.gz
#
#
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100730_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100010_0001.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100889_0001.nii.gz
#
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100806_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100546_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100930_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100853_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100031_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100010_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100891_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100261_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100186_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100371_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100889_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100681_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100730_0002.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100175_0000.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100397_0001.nii.gz
#
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100460_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100546_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100806_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100930_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100031_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100031/30/opportunistic-screening/seg.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100853_0002.nii.gzSubject: 100031, Mask files found: 1
#
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100010_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100010/30/opportunistic-screening/seg.nii.gz
# Subject: 100010, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100031.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100978/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100010.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100394/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100978, Files found: 1
# Subject: 100394, Files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100891_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100261_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100186_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100889_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100889/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100546_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100546/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100806_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100806/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100371_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100371/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100730_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100730/30/opportunistic-screening/seg.nii.gz
# Subject: 100889, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100930_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100930/30/opportunistic-screening/seg.nii.gz
# Subject: 100546, Mask files found: 1  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100853_0003.nii.gzSubject: 100806, Mask files found: 1
#
# Subject: 100371, Mask files found: 1
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100853/30/opportunistic-screening/seg.nii.gzSubject: 100730, Mask files found: 1
#
#
# Subject: 100930, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100681_0002.nii.gz
# Subject: 100853, Mask files found: 1
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100175_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100460_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100261_0002.nii.gz  Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100397_0002.nii.gz  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100891_0003.nii.gz
#
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100891/30/opportunistic-screening/seg.nii.gz
# Subject: 100891, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100546.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100219/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100889.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100806.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100383/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100877/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100730.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100689/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100219, Files found: 1
# Subject: 100383, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100930.nii.gz
# Subject: 100877, Files found: 1  Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100371.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100088/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100721/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100689, Files found: 1
# Subject: 100721, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100853.nii.gzSubject: 100088, Files found: 1
#
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100480/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100891.nii.gz  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100186_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100186/30/opportunistic-screening/seg.nii.gz
#
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100122/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100186, Mask files found: 1
# Subject: 100480, Files found: 1
# Subject: 100122, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100261_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100261/30/opportunistic-screening/seg.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100186.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100779/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100261, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100175_0002.nii.gzSubject: 100779, Files found: 1  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100681_0003.nii.gz  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100460_0003.nii.gz
#
#
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100681/30/opportunistic-screening/seg.nii.gzLooking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100460/30/opportunistic-screening/seg.nii.gz
#
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100397_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100397/30/opportunistic-screening/seg.nii.gz
# Subject: 100681, Mask files found: 1Subject: 100460, Mask files found: 1
#
# Subject: 100397, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100261.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100800/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100800, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100681.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100810/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100397.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100028/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100460.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100642/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100810, Files found: 1
# Subject: 100028, Files found: 1
# Subject: 100642, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100175_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100175/30/opportunistic-screening/seg.nii.gz
# Subject: 100175, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100175.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100988/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100988, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100394_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100978_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100394_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100978_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100394_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100978_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100394_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100394/30/opportunistic-screening/seg.nii.gz
# Subject: 100394, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100978_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100978/30/opportunistic-screening/seg.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100394.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100972/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100978, Mask files found: 1
# Subject: 100972, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100689_0000.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100978.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100420/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100420, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100877_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100122_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100721_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100480_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100383_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100088_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100779_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100219_0000.nii.gz
#
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100689_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100877_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100122_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100721_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100480_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100383_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100122_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100088_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100877_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100779_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100689_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100219_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100800_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100810_0000.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100721_0002.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100028_0000.nii.gz
#
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100480_0002.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100642_0000.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100122_0003.nii.gz  Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100383_0002.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100122/30/opportunistic-screening/seg.nii.gz
# Subject: 100122, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100088_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100122.nii.gz  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100877_0003.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100877/30/opportunistic-screening/seg.nii.gzLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100622/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#
# Subject: 100877, Mask files found: 1
# Subject: 100622, Files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100779_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100877.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100805/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100689_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100689/30/opportunistic-screening/seg.nii.gz
# Subject: 100689, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100721_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100721/30/opportunistic-screening/seg.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100988_0000.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100480_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100480/30/opportunistic-screening/seg.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100800_0001.nii.gz
# Subject: 100721, Mask files found: 1
# Subject: 100480, Mask files found: 1
# Subject: 100805, Files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100219_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100088_0003.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100028_0001.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100810_0001.nii.gz
#
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100088/30/opportunistic-screening/seg.nii.gz
# Subject: 100088, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100383_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100383/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100779_0003.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100642_0001.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100779/30/opportunistic-screening/seg.nii.gz
# Subject: 100383, Mask files found: 1
# Subject: 100779, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100689.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100499/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100721.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100649/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100480.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100041/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100499, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100088.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100258/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100649, Files found: 1
# Subject: 100041, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100383.nii.gz
# Subject: 100258, Files found: 1Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100090/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100779.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100009/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100090, Files found: 1
# Subject: 100009, Files found: 1
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100988_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100800_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100219_0003.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100810_0002.nii.gzLooking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100219/30/opportunistic-screening/seg.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100642_0002.nii.gz  Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100028_0002.nii.gz
#
#
# Subject: 100219, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100219.nii.gz  Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100988_0002.nii.gz
#
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100331/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100331, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100800_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100800/30/opportunistic-screening/seg.nii.gz
# Subject: 100800, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100810_0003.nii.gz  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100028_0003.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100028/30/opportunistic-screening/seg.nii.gzLooking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100810/30/opportunistic-screening/seg.nii.gz
#
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100642_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100642/30/opportunistic-screening/seg.nii.gz
# Subject: 100028, Mask files found: 1
# Subject: 100810, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100988_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100988/30/opportunistic-screening/seg.nii.gz
# Subject: 100642, Mask files found: 1
# Subject: 100988, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100800.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100474/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100810.nii.gz  Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100028.nii.gz
#
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100092/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100816/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100642.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100177/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100092, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100988.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100335/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100474, Files found: 1
# Subject: 100816, Files found: 1
# Subject: 100177, Files found: 1
# Subject: 100335, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100092_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100092_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100092_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100092_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100092/30/opportunistic-screening/seg.nii.gz
# Subject: 100092, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100092.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100521/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100521, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100420_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100972_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100972_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100420_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100972_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100420_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100420_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100420/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100972_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100972/30/opportunistic-screening/seg.nii.gz
# Subject: 100420, Mask files found: 1
# Subject: 100972, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100420.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100022/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100972.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100453/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100022, Files found: 1
# Subject: 100453, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100622_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100622_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100805_0000.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100622_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100622_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100622/30/opportunistic-screening/seg.nii.gz
# Subject: 100622, Mask files found: 1
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100805_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100499_0000.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100622.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100081/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100041_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100649_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100258_0000.nii.gz
#
# Subject: 100081, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100090_0000.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100805_0002.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100009_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100499_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100041_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100649_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100258_0001.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100805_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100805/30/opportunistic-screening/seg.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100090_0001.nii.gz
# Subject: 100805, Mask files found: 1  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100009_0001.nii.gz
#
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100499_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100041_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100649_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTr/100805.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100606/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100258_0002.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100331_0000.nii.gz
# Subject: 100606, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTr/100041_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100041/30/opportunistic-screening/seg.nii.gz
# ...
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100789/30/opportunistic-screening/seg.nii.gz
# Subject: 100789, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100210_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100210/30/opportunistic-screening/seg.nii.gz
# Subject: 100210, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100865.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100330_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100330/30/opportunistic-screening/seg.nii.gzLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100671/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii  Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100838.nii.gz
#
#
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100239.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100387/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100899/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiSubject: 100330, Mask files found: 1
#
# Subject: 100671, Files found: 1
# Subject: 100387, Files found: 1
# Subject: 100899, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100264.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100675/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100675, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100623.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100532/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100872.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100750/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100210.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100447/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100789.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100456/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100330.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100278_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100278/30/opportunistic-screening/seg.nii.gz
# Subject: 100278, Mask files found: 1  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100808_0001.nii.gz
#
# Subject: 100532, Files found: 1
# Subject: 100750, Files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100224_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100509_0002.nii.gz
# Subject: 100447, Files found: 1
# Subject: 100456, Files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100643_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100278.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100675_0000.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100808_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100224_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100224/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100509_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100509/30/opportunistic-screening/seg.nii.gz
# Subject: 100224, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100643_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100643/30/opportunistic-screening/seg.nii.gz
# Subject: 100509, Mask files found: 1
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100675_0001.nii.gz
# Subject: 100643, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100808_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100808/30/opportunistic-screening/seg.nii.gz
# Subject: 100808, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100224.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100509.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100643.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100675_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100808.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100675_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100675/30/opportunistic-screening/seg.nii.gz
# Subject: 100675, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100675.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100744_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100532_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100594_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100899_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100456_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100387_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100447_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100750_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100671_0000.nii.gz
#
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100532_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100744_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100899_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100594_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100456_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100387_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100447_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100532_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100750_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100899_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100671_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100456_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100594_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100744_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100387_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100532_0003.nii.gz  Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100447_0002.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100532/30/opportunistic-screening/seg.nii.gz
# Subject: 100532, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100750_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100899_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100899/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100456_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100456/30/opportunistic-screening/seg.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100532.nii.gz
# Subject: 100899, Mask files found: 1
# Subject: 100456, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100594_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100594/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100387_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100387/30/opportunistic-screening/seg.nii.gz
# Subject: 100594, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100671_0002.nii.gz
# Subject: 100387, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100744_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100744/30/opportunistic-screening/seg.nii.gz
# Subject: 100744, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100447_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100447/30/opportunistic-screening/seg.nii.gz
# Subject: 100447, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100899.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100456.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100594.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100387.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100750_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100750/30/opportunistic-screening/seg.nii.gz
# Subject: 100750, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100744.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100447.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100750.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/imagesTs/100671_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100671/30/opportunistic-screening/seg.nii.gz
# Subject: 100671, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset005_oppscreen_100/labelsTs/100671.nii.gz

# %% [markdown]
# export nnUNet_raw="/nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw"
# export nnUNet_preprocessed="/nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_preprocessed"
# export nnUNet_results="/nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_results"
#
# uv run nnUNetv2_plan_and_preprocess --n-workers 10 -d 5 --verify_dataset_integrity -c 3d_fullres -pl nnUNetPlannerResEncM -gpu_memory_target 40 -overwrite_plans_name nnUNetResEncUNetPlans_40G
# uv run nnUNetv2_train 5 3d_fullres -p nnUNetResEncUNetPlans_40G 0
