# %%
# relative path
from hydra import compose, initialize
from omegaconf import OmegaConf

with initialize(config_path="dev/whole_body_benchmark/configs"):
    cfg = compose(config_name="config")

print(OmegaConf.to_yaml(cfg))
# Out:
# /tmp/ipykernel_65/435518771.py:5: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   with initialize(config_path="dev/whole_body_benchmark/configs"):
# paths:
#   nako_dir: /nfs/data/nii/data0/GNC/GNC_759
#   nnUNet_dir: /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/

# %%
# create nnUNet_raw, nnUNet_preprocessed, nnUNet_results
import os
os.makedirs(cfg.paths.nnUNet_dir + "/nnUNet_raw", exist_ok=True)
os.makedirs(cfg.paths.nnUNet_dir + "/nnUNet_preprocessed", exist_ok=True)
os.makedirs(cfg.paths.nnUNet_dir + "/nnUNet_results", exist_ok=True)

raw_ds_dir = os.path.join(cfg.paths.nnUNet_dir, "nnUNet_raw/Dataset004_Nako_oppscreen")
os.makedirs(raw_ds_dir, exist_ok=True)
os.makedirs(os.path.join(raw_ds_dir, "imagesTr"), exist_ok=True)
os.makedirs(os.path.join(raw_ds_dir, "labelsTr"), exist_ok=True)
os.makedirs(os.path.join(raw_ds_dir, "imagesTs"), exist_ok=True)
os.makedirs(os.path.join(raw_ds_dir, "labelsTs"), exist_ok=True)

# %%
nb_subjects = 100
from pathlib import Path
import glob
img_base_path = Path(cfg.paths.nako_dir) / "links"
mask_base_path = Path(cfg.paths.nako_dir) / "data"
img_target = "30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii"
mask_target = "30/opportunistic-screening/seg.nii.gz"
subjects = [e.name for e in os.scandir(img_base_path) if e.is_dir()][:50000]
# keep subdirs where opportunistic-screening/seg.nii.gz" exists
valid_subjects = []
for subject in subjects:
    mask_path = os.path.join(mask_base_path, subject, mask_target)
    if os.path.exists(mask_path):
        valid_subjects.append(subject)
print("Valid subjects:", len(valid_subjects))
# randomly select nb_subjects from valid_subjects
import random
random.seed(42)
random.shuffle(valid_subjects)
subjects = valid_subjects[:nb_subjects]
subjects_train = subjects[:int(0.8*len(subjects))]
subjects_test = subjects[int(0.8*len(subjects)):]
print("Train subjects:", len(subjects_train))
print("Test subjects:", len(subjects_test))
# Out:
# Valid subjects: 966
# Train subjects: 80
# Test subjects: 20

# %%
"""
import nibabel as nib
import numpy as np
uniques_values = []
for subject in subjects:
    mask_path = os.path.join(mask_base_path, subject, mask_target)
    mask = nib.load(mask_path)
    mask_data = mask.get_fdata()
    unique = np.unique(mask_data)
    uniques_values.append(unique)
# distribution of unique values in the masks
lens=[len(unique) for unique in uniques_values]
print("Unique values distribution:", np.bincount(lens))
"""

# %%
import nibabel as nib
import numpy as np
import shutil

def process_subject(subject, img_base_path, mask_base_path, img_target, mask_target, images_dir, labels_dir):
    img_path = img_base_path / subject / img_target
    mask_path = mask_base_path / subject / mask_target

    # --- Images: split 4D -> 4x 3D channel files ---
    print(f"Looking for images in: {img_path}")
    files = glob.glob(str(img_path))
    print(f"Subject: {subject}, Files found: {len(files)}")

    if len(files) > 0:
        img = nib.load(files[0])
        data = img.get_fdata()  # (320, 260, 316, 4)

        if data.ndim == 4:
            for ch in range(data.shape[-1]):
                channel_data = data[..., ch].astype(np.float32)
                new_img = nib.Nifti1Image(channel_data, img.affine, img.header)
                new_img.header.set_data_shape(channel_data.shape)
                dst = os.path.join(images_dir, f"{subject}_{ch:04d}.nii.gz")
                nib.save(new_img, dst)
                print(f"  Saved channel {ch} -> {dst}")
        else:
            # skip if not 4D
            print(f"  Warning: Image is not 4D, skipping: {files[0]}")

    # --- Mask: enforce 3D header and save ---
    print(f"Looking for masks in: {mask_path}")
    mask_files = glob.glob(str(mask_path))
    print(f"Subject: {subject}, Mask files found: {len(mask_files)}")

    if len(mask_files) > 0:
        mask = nib.load(mask_files[0])
        mask_data = mask.get_fdata().astype(np.uint8)

        # Squeeze out any phantom 4th dim
        if mask_data.ndim == 4:
            mask_data = mask_data[..., 0]

        new_mask = nib.Nifti1Image(mask_data, mask.affine, mask.header)
        new_mask.header.set_data_shape(mask_data.shape)
        dst = os.path.join(labels_dir, f"{subject}.nii.gz")
        nib.save(new_mask, dst)
        print(f"  Saved mask -> {dst}")


from concurrent.futures import ProcessPoolExecutor, as_completed

def run_parallel(subjects, images_dir, labels_dir, max_workers=16):
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        futures = {
            executor.submit(
                process_subject,
                subject,
                img_base_path, mask_base_path,
                img_target, mask_target,
                images_dir, labels_dir,
            ): subject
            for subject in subjects
        }
        for future in as_completed(futures):
            subject = futures[future]
            try:
                future.result()
            except Exception as e:
                print(f"ERROR processing {subject}: {e}")

run_parallel(subjects_train,
             os.path.join(raw_ds_dir, "imagesTr"),
             os.path.join(raw_ds_dir, "labelsTr"))

run_parallel(subjects_test,
             os.path.join(raw_ds_dir, "imagesTs"),
             os.path.join(raw_ds_dir, "labelsTs"))
# Out:
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100901/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100537/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100018/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100058/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100573/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100381/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100360/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100137/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100452/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100736/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100401/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100626/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100384/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100271/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100311/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100550/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Subject: 100311, Files found: 1
# Subject: 100137, Files found: 1Subject: 100401, Files found: 1
#
# Subject: 100271, Files found: 1Subject: 100018, Files found: 1Subject: 100058, Files found: 1
#
#
# Subject: 100550, Files found: 1Subject: 100573, Files found: 1
#
# Subject: 100384, Files found: 1Subject: 100626, Files found: 1Subject: 100537, Files found: 1
#
# Subject: 100452, Files found: 1Subject: 100360, Files found: 1
#
#
# Subject: 100736, Files found: 1
# Subject: 100381, Files found: 1
# Subject: 100901, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100058_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100401_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100018_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100736_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100311_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100381_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100384_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100901_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100626_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100452_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100573_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100137_0000.nii.gz
#
#
#
#
#
#
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100058_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100271_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100550_0000.nii.gz
#
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100401_0001.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100360_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100537_0000.nii.gz
#
#
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100901_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100736_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100018_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100384_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100573_0001.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100381_0001.nii.gz
#
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100058_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100311_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100452_0001.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100137_0001.nii.gz
#
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100626_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100401_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100901_0002.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100550_0001.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100360_0001.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100537_0001.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100271_0001.nii.gz
#
#
#
#
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100736_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100018_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100384_0002.nii.gz  Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100573_0002.nii.gz
#
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100381_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100058_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100058/30/opportunistic-screening/seg.nii.gz
# Subject: 100058, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100058.nii.gz  Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100311_0002.nii.gz
#
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100680/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100680, Files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100137_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100452_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100901_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100901/30/opportunistic-screening/seg.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100626_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100401_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100401/30/opportunistic-screening/seg.nii.gz
# Subject: 100901, Mask files found: 1
# Subject: 100401, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100736_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100736/30/opportunistic-screening/seg.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100537_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100271_0002.nii.gz
# Subject: 100736, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100384_0003.nii.gz  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100573_0003.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100384/30/opportunistic-screening/seg.nii.gzLooking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100573/30/opportunistic-screening/seg.nii.gz
#
# Subject: 100384, Mask files found: 1
# Subject: 100573, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100360_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100550_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100018_0003.nii.gz  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100381_0003.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100018/30/opportunistic-screening/seg.nii.gzLooking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100381/30/opportunistic-screening/seg.nii.gz
#
# Subject: 100018, Mask files found: 1Subject: 100381, Mask files found: 1
#
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100311_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100311/30/opportunistic-screening/seg.nii.gz
# Subject: 100311, Mask files found: 1  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100452_0003.nii.gz  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100626_0003.nii.gz  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100137_0003.nii.gz
#
#
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100452/30/opportunistic-screening/seg.nii.gzLooking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100626/30/opportunistic-screening/seg.nii.gzLooking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100137/30/opportunistic-screening/seg.nii.gz
#
#
# Subject: 100452, Mask files found: 1Subject: 100137, Mask files found: 1
# Subject: 100626, Mask files found: 1
#
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100901.nii.gz  Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100401.nii.gz
#
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100231/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100540/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#
# Subject: 100540, Files found: 1
# Subject: 100231, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100736.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100997/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100537_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100537/30/opportunistic-screening/seg.nii.gz
# Subject: 100997, Files found: 1
# Subject: 100537, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100271_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100271/30/opportunistic-screening/seg.nii.gz
# Subject: 100271, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100384.nii.gz  Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100360_0003.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100360/30/opportunistic-screening/seg.nii.gzLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100842/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#
# Subject: 100360, Mask files found: 1
# Subject: 100842, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100573.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100840/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100550_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100550/30/opportunistic-screening/seg.nii.gz
# Subject: 100550, Mask files found: 1
# Subject: 100840, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100018.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100959/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100959, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100381.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100311.nii.gz  Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100137.nii.gz
#
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100131/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100970/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100310/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#
# Subject: 100131, Files found: 1Subject: 100310, Files found: 1
#
# Subject: 100970, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100452.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100119/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100626.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100746/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100119, Files found: 1
# Subject: 100746, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100537.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100195/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100271.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100727/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100360.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100927/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100195, Files found: 1
# Subject: 100727, Files found: 1
# Subject: 100927, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100550.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100926/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100926, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100680_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100680_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100680_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100680_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100680/30/opportunistic-screening/seg.nii.gz
# Subject: 100680, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100680.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100653/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100653, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100231_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100540_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100231_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100540_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100231_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100540_0002.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100842_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100840_0000.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100231_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100231/30/opportunistic-screening/seg.nii.gz
# Subject: 100231, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100540_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100540/30/opportunistic-screening/seg.nii.gz
# Subject: 100540, Mask files found: 1
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100842_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100840_0001.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100231.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100929/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100929, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100540.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100965/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100310_0000.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100842_0002.nii.gz
# Subject: 100965, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100959_0000.nii.gz  Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100840_0002.nii.gz
#
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100970_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100997_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100131_0000.nii.gz
#
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100927_0000.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100842_0003.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100310_0001.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100842/30/opportunistic-screening/seg.nii.gz
# Subject: 100842, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100840_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100840/30/opportunistic-screening/seg.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100959_0001.nii.gz
# Subject: 100840, Mask files found: 1
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100970_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100195_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100746_0000.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100842.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100715/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100727_0000.nii.gz
# Subject: 100715, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100926_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100119_0000.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100840.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100019/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100997_0001.nii.gz
#
# Subject: 100019, Files found: 1
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100131_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100310_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100927_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100959_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100970_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100195_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100727_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100926_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100746_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100997_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100119_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100131_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100310_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100310/30/opportunistic-screening/seg.nii.gz
# Subject: 100310, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100959_0003.nii.gz  Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100927_0002.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100959/30/opportunistic-screening/seg.nii.gz
# Subject: 100959, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100970_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100970/30/opportunistic-screening/seg.nii.gz
# Subject: 100970, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100195_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100727_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100310.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100856/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100926_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100959.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100980/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100856, Files found: 1
# Subject: 100980, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100997_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100997/30/opportunistic-screening/seg.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100746_0002.nii.gz
# Subject: 100997, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100970.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100517/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100119_0002.nii.gz
# Subject: 100517, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100131_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100131/30/opportunistic-screening/seg.nii.gz
# Subject: 100131, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100927_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100927/30/opportunistic-screening/seg.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100653_0000.nii.gz
# Subject: 100927, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100997.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100720/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100720, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100195_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100195/30/opportunistic-screening/seg.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100131.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100464/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100195, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100727_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100727/30/opportunistic-screening/seg.nii.gz
# Subject: 100727, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100926_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100926/30/opportunistic-screening/seg.nii.gz
# Subject: 100464, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100927.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100825/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100926, Mask files found: 1
# Subject: 100825, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100746_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100746/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100119_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100119/30/opportunistic-screening/seg.nii.gz
# Subject: 100746, Mask files found: 1  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100653_0001.nii.gz
#
# Subject: 100119, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100195.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100198/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100198, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100727.nii.gz  Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100926.nii.gz
#
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100544/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100284/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#
# Subject: 100544, Files found: 1
# Subject: 100284, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100119.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100221/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100746.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100123/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100221, Files found: 1
# Subject: 100123, Files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100653_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100653_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100653/30/opportunistic-screening/seg.nii.gz
# Subject: 100653, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100653.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100804/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100804, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100929_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100965_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100929_0001.nii.gz  Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100965_0001.nii.gz
#
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100929_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100965_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100929_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100929/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100965_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100965/30/opportunistic-screening/seg.nii.gz
# Subject: 100929, Mask files found: 1
# Subject: 100965, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100929.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100432/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100965.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100762/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100432, Files found: 1
# Subject: 100762, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100715_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100715_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100019_0000.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100715_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100019_0001.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100715_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100715/30/opportunistic-screening/seg.nii.gz
# Subject: 100715, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100019_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100715.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100802/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100802, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100019_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100019/30/opportunistic-screening/seg.nii.gz
# Subject: 100019, Mask files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100856_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100517_0000.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100019.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100856_0001.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100470/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100980_0000.nii.gz
# Subject: 100470, Files found: 1
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100517_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100856_0002.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100720_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100464_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100980_0001.nii.gz  Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100825_0000.nii.gz
#
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100517_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100856_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100856/30/opportunistic-screening/seg.nii.gz
# Subject: 100856, Mask files found: 1
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100720_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100284_0000.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100856.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100409/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100464_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100198_0000.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100980_0002.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100221_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100123_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100825_0001.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100517_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100517/30/opportunistic-screening/seg.nii.gz
# Subject: 100409, Files found: 1
# Subject: 100517, Mask files found: 1
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100544_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100284_0001.nii.gz  Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100720_0002.nii.gz
#
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTr/100517.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100869/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTr/100464_0002.nii.gz
# Subject: 100869, Files found: 1
# ...
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100675_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100553_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100092_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100823_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100717_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100787_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100129_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100183_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100404_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100683_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100652_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100908_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100880_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100339_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100624_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100916_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100675_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100553_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100092_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100717_0002.nii.gz  Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100823_0002.nii.gz
#
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100787_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100129_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100129/30/opportunistic-screening/seg.nii.gz
# Subject: 100129, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100183_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100404_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100129.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100835/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100683_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100683/30/opportunistic-screening/seg.nii.gz
# Subject: 100683, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100652_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100880_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100880/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100908_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100908/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100624_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100624/30/opportunistic-screening/seg.nii.gz
# Subject: 100880, Mask files found: 1Subject: 100908, Mask files found: 1
#
# Subject: 100835, Files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100339_0002.nii.gz
# Subject: 100624, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100553_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100553/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100916_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100916/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100092_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100092/30/opportunistic-screening/seg.nii.gz
# Subject: 100553, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100675_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100675/30/opportunistic-screening/seg.nii.gz
# Subject: 100916, Mask files found: 1
# Subject: 100092, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100717_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100717/30/opportunistic-screening/seg.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100683.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100554/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100823_0003.nii.gzSubject: 100675, Mask files found: 1
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100823/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100787_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100787/30/opportunistic-screening/seg.nii.gz
# Subject: 100717, Mask files found: 1
# Subject: 100823, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100183_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100183/30/opportunistic-screening/seg.nii.gz
# Subject: 100787, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100880.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100250/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100183, Mask files found: 1
# Subject: 100554, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100404_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100404/30/opportunistic-screening/seg.nii.gz
# Subject: 100250, Files found: 1
# Subject: 100404, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100652_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100652/30/opportunistic-screening/seg.nii.gz
# Subject: 100652, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100908.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100339_0003.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100868/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100339/30/opportunistic-screening/seg.nii.gz
#
# Subject: 100339, Mask files found: 1
# Subject: 100868, Files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100624.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100553.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100916.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100092.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100675.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100717.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100404.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100823.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100183.nii.gz  Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100787.nii.gz  Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100652.nii.gz
#
#
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100339.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100835_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100868_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100835_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100554_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100250_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100868_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100835_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100554_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100250_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100868_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100835_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100835/30/opportunistic-screening/seg.nii.gz
# Subject: 100835, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100554_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100835.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100868_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100868/30/opportunistic-screening/seg.nii.gz
# Subject: 100868, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100250_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100554_0003.nii.gz  Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100868.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100554/30/opportunistic-screening/seg.nii.gz
# Subject: 100554, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100554.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/imagesTs/100250_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100250/30/opportunistic-screening/seg.nii.gz
# Subject: 100250, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw/Dataset004_Nako_oppscreen/labelsTs/100250.nii.gz

# %% [markdown]
# export nnUNet_raw="/nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_raw"
# export nnUNet_preprocessed="/nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_preprocessed"
# export nnUNet_results="/nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/nnUNet/nnUNet_results"
#
# uv run nnUNetv2_plan_and_preprocess -d 4 --verify_dataset_integrity -pl nnUNetPlannerResEncM -gpu_memory_target 40
# uv run nnUNetv2_train 4 3d_fullres -p nnUNetResEncUNetMPlans 0
