# %%
from hydra import compose, initialize
from omegaconf import OmegaConf
import json
import os
from pathlib import Path
import glob
with initialize(config_path="dev/whole_body_benchmark/configs"):
    cfg = compose(config_name="config")

print(OmegaConf.to_yaml(cfg))
# Out:
# /tmp/ipykernel_90/1456265780.py:7: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   with initialize(config_path="dev/whole_body_benchmark/configs"):
# paths:
#   nako_dir: /nfs/data/nii/data0/GNC/GNC_759
#   nnUNet_dir: /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/
#   results_dir: /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/results/
#   data_dir: /nfs/data/nii/data0/GNC/Analysis/GNC_759/ANALYSIS_whole_body_benchmark/data/
#   oppscreen_dir: /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/data/oppscreen/

# %%
out_path = Path(cfg.paths.data_dir) / 'splits_966.json'
with open(out_path, 'r') as f:
    splits = json.load(f)

# %%
subjects_train, subjects_test = splits['train_20'], splits['test']
dataset_name = "Dataset003_oppscreen_20_subjects"

# %%
img_base_path = Path(cfg.paths.nako_dir) / "links"
mask_base_path = Path(cfg.paths.nako_dir) / "data"
img_target = "30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii"
mask_target = "30/opportunistic-screening/seg.nii.gz"
os.makedirs(cfg.paths.nnUNet_dir + "/nnUNet_raw", exist_ok=True)
os.makedirs(cfg.paths.nnUNet_dir + "/nnUNet_preprocessed", exist_ok=True)
os.makedirs(cfg.paths.nnUNet_dir + "/nnUNet_results", exist_ok=True)

raw_ds_dir = os.path.join(cfg.paths.nnUNet_dir, f"nnUNet_raw/{dataset_name}")
os.makedirs(raw_ds_dir, exist_ok=True)
os.makedirs(os.path.join(raw_ds_dir, "imagesTr"), exist_ok=True)
os.makedirs(os.path.join(raw_ds_dir, "labelsTr"), exist_ok=True)
os.makedirs(os.path.join(raw_ds_dir, "imagesTs"), exist_ok=True)
os.makedirs(os.path.join(raw_ds_dir, "labelsTs"), exist_ok=True)

# %%
import nibabel as nib
import numpy as np
import shutil

def process_subject(subject, img_base_path, mask_base_path, img_target, mask_target, images_dir, labels_dir):
    img_path = img_base_path / subject / img_target
    mask_path = mask_base_path / subject / mask_target

    # --- Images: split 4D -> 4x 3D channel files ---
    print(f"Looking for images in: {img_path}")
    files = glob.glob(str(img_path))
    print(f"Subject: {subject}, Files found: {len(files)}")

    if len(files) > 0:
        img = nib.load(files[0])
        data = img.get_fdata()  # (320, 260, 316, 4)

        if data.ndim == 4:
            for ch in range(data.shape[-1]):
                channel_data = data[..., ch].astype(np.float32)
                new_img = nib.Nifti1Image(channel_data, img.affine, img.header)
                new_img.header.set_data_shape(channel_data.shape)
                dst = os.path.join(images_dir, f"{subject}_{ch:04d}.nii.gz")
                nib.save(new_img, dst)
                print(f"  Saved channel {ch} -> {dst}")
        else:
            # skip if not 4D
            print(f"  Warning: Image is not 4D, skipping: {files[0]}")

    # --- Mask: enforce 3D header and save ---
    print(f"Looking for masks in: {mask_path}")
    mask_files = glob.glob(str(mask_path))
    print(f"Subject: {subject}, Mask files found: {len(mask_files)}")

    if len(mask_files) > 0:
        mask = nib.load(mask_files[0])
        mask_data = mask.get_fdata().astype(np.uint8)

        # Squeeze out any phantom 4th dim
        if mask_data.ndim == 4:
            mask_data = mask_data[..., 0]

        new_mask = nib.Nifti1Image(mask_data, mask.affine, mask.header)
        new_mask.header.set_data_shape(mask_data.shape)
        dst = os.path.join(labels_dir, f"{subject}.nii.gz")
        nib.save(new_mask, dst)
        print(f"  Saved mask -> {dst}")


from concurrent.futures import ProcessPoolExecutor, as_completed

def run_parallel(subjects, images_dir, labels_dir, max_workers=16):
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        futures = {
            executor.submit(
                process_subject,
                subject,
                img_base_path, mask_base_path,
                img_target, mask_target,
                images_dir, labels_dir,
            ): subject
            for subject in subjects
        }
        for future in as_completed(futures):
            subject = futures[future]
            try:
                future.result()
            except Exception as e:
                print(f"ERROR processing {subject}: {e}")

run_parallel(subjects_train,
             os.path.join(raw_ds_dir, "imagesTr"),
             os.path.join(raw_ds_dir, "labelsTr"))

run_parallel(subjects_test,
             os.path.join(raw_ds_dir, "imagesTs"),
             os.path.join(raw_ds_dir, "labelsTs"))
# Out:
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100901/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100018/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100537/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100573/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100360/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100736/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100381/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100058/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100137/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100626/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100452/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100311/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100401/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100271/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100384/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100550/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Subject: 100311, Files found: 1
# Subject: 100736, Files found: 1
# Subject: 100384, Files found: 1Subject: 100573, Files found: 1
#
# Subject: 100271, Files found: 1Subject: 100058, Files found: 1Subject: 100550, Files found: 1
# Subject: 100137, Files found: 1
# Subject: 100018, Files found: 1
# Subject: 100901, Files found: 1Subject: 100381, Files found: 1
#
# Subject: 100626, Files found: 1
#
# Subject: 100537, Files found: 1
#
# Subject: 100401, Files found: 1
# Subject: 100360, Files found: 1
# Subject: 100452, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100384_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100626_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100901_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100573_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100381_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100452_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100736_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100537_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100058_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100018_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100360_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100384_0001.nii.gz  Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100401_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100550_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100311_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100137_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100271_0000.nii.gz
#
#
#
#
#
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100626_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100901_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100573_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100381_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100452_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100736_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100537_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100058_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100018_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100384_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100137_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100360_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100271_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100401_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100901_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100381_0002.nii.gz  Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100626_0002.nii.gz
#
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100311_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100573_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100550_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100452_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100736_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100058_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100537_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100018_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100384_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100384/30/opportunistic-screening/seg.nii.gz
# Subject: 100384, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100137_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100384.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100680/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100680, Files found: 1
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100360_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100901_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100901/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100381_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100381/30/opportunistic-screening/seg.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100401_0002.nii.gz
# Subject: 100901, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100271_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100626_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100626/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100452_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100452/30/opportunistic-screening/seg.nii.gz
# Subject: 100381, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100736_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100736/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100573_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100573/30/opportunistic-screening/seg.nii.gz
# Subject: 100626, Mask files found: 1
# Subject: 100452, Mask files found: 1  Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100550_0002.nii.gz  Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100311_0002.nii.gzSubject: 100736, Mask files found: 1Subject: 100573, Mask files found: 1
#
#
#
#
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100058_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100058/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100537_0003.nii.gz  Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100137_0003.nii.gz  Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100018_0003.nii.gz
#
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100537/30/opportunistic-screening/seg.nii.gzLooking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100018/30/opportunistic-screening/seg.nii.gzLooking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100137/30/opportunistic-screening/seg.nii.gz
#
#
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100360_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100360/30/opportunistic-screening/seg.nii.gz
# Subject: 100058, Mask files found: 1Subject: 100537, Mask files found: 1
#
# Subject: 100018, Mask files found: 1Subject: 100137, Mask files found: 1Subject: 100360, Mask files found: 1
#
#
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100901.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100231/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100381.nii.gz
# Subject: 100231, Files found: 1
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100540/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100540, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100401_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100401/30/opportunistic-screening/seg.nii.gz
# Subject: 100401, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100452.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100997/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100997, Files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100573.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100736.nii.gz  Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100271_0003.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100271/30/opportunistic-screening/seg.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100626.nii.gz
# Subject: 100271, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100537.nii.gz  Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100311_0003.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100311/30/opportunistic-screening/seg.nii.gz
# Subject: 100311, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100550_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100550/30/opportunistic-screening/seg.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100018.nii.gz
# Subject: 100550, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100058.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100360.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100137.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100401.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100271.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100311.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100550.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100680_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100540_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100997_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100231_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100680_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100540_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100997_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100231_0001.nii.gz  Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100680_0002.nii.gz
#
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100540_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100997_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100680_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100680/30/opportunistic-screening/seg.nii.gz
# Subject: 100680, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100231_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100680.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100540_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100540/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100997_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100997/30/opportunistic-screening/seg.nii.gz
# Subject: 100540, Mask files found: 1Subject: 100997, Mask files found: 1
#
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTr/100231_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100231/30/opportunistic-screening/seg.nii.gz
# Subject: 100231, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100997.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100540.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTr/100231.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100847/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100161/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100963/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100500/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100784/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100193/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100263/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100383/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100235/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100651/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100256/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#
#
#
#
#
#
#
#
#
#
# Subject: 100847, Files found: 1
# Subject: 100651, Files found: 1
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100824/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100039/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100374/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100082/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiLooking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100668/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.niiSubject: 100784, Files found: 1
# Subject: 100235, Files found: 1Subject: 100161, Files found: 1
#
# Subject: 100256, Files found: 1
#
#
#
#
#
# Subject: 100383, Files found: 1
# Subject: 100263, Files found: 1
# Subject: 100963, Files found: 1Subject: 100374, Files found: 1
# Subject: 100193, Files found: 1
#
# Subject: 100039, Files found: 1
# Subject: 100500, Files found: 1
# Subject: 100824, Files found: 1Subject: 100668, Files found: 1
#
# Subject: 100082, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100039_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100256_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100500_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100161_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100668_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100847_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100263_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100963_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100784_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100824_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100651_0000.nii.gz
#
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100039_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100383_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100082_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100256_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100193_0000.nii.gz  Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100235_0000.nii.gz
#
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100374_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100500_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100161_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100668_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100847_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100263_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100963_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100784_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100039_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100824_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100082_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100500_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100651_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100256_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100193_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100668_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100235_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100161_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100263_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100383_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100784_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100374_0001.nii.gz  Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100847_0002.nii.gz
#
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100039_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100039/30/opportunistic-screening/seg.nii.gz
# Subject: 100039, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100963_0002.nii.gz  Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100824_0002.nii.gz  Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100082_0002.nii.gz
#
#
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100500_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100500/30/opportunistic-screening/seg.nii.gz
# Subject: 100500, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100039.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100312/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100651_0002.nii.gz
# Subject: 100312, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100256_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100256/30/opportunistic-screening/seg.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100500.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100229/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100256, Mask files found: 1
# Subject: 100229, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100668_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100668/30/opportunistic-screening/seg.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100193_0002.nii.gz
# Subject: 100668, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100235_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100161_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100161/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100263_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100263/30/opportunistic-screening/seg.nii.gz
# Subject: 100161, Mask files found: 1
# Subject: 100263, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100784_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100784/30/opportunistic-screening/seg.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100383_0002.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100256.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100280/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100847_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100847/30/opportunistic-screening/seg.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100082_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100082/30/opportunistic-screening/seg.nii.gz
# Subject: 100784, Mask files found: 1
# Subject: 100847, Mask files found: 1
# Subject: 100082, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100374_0002.nii.gzSubject: 100280, Files found: 1
#
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100668.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100785/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100963_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100963/30/opportunistic-screening/seg.nii.gz
# Subject: 100785, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100824_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100824/30/opportunistic-screening/seg.nii.gz
# Subject: 100963, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100651_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100651/30/opportunistic-screening/seg.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100161.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100020/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100824, Mask files found: 1
# Subject: 100651, Mask files found: 1  Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100193_0003.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100193/30/opportunistic-screening/seg.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100263.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100334/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100235_0003.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100784.nii.gzLooking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100235/30/opportunistic-screening/seg.nii.gz
#
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100630/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100383_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100383/30/opportunistic-screening/seg.nii.gz
# Subject: 100193, Mask files found: 1
# Subject: 100020, Files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100847.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100697/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100235, Mask files found: 1  Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100082.nii.gz
#
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100952/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100383, Mask files found: 1
# Subject: 100334, Files found: 1
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100374_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100374/30/opportunistic-screening/seg.nii.gz
# Subject: 100630, Files found: 1
# Subject: 100374, Mask files found: 1
# Subject: 100697, Files found: 1
# Subject: 100952, Files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100824.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100703/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100651.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100042/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100703, Files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100963.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100882/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100042, Files found: 1
# Subject: 100882, Files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100193.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100822/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100235.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100831/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100383.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100024/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100822, Files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100374.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100996/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100831, Files found: 1
# Subject: 100024, Files found: 1
# Subject: 100996, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100229_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100312_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100280_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100229_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100312_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100334_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100280_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100020_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100630_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100697_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100785_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100703_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100952_0000.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100229_0002.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100882_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100042_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100831_0000.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100312_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100280_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100334_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100024_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100020_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100630_0001.nii.gz
# ...
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100117_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100117/30/opportunistic-screening/seg.nii.gz
# Subject: 100117, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100692_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100479_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100479/30/opportunistic-screening/seg.nii.gz
# Subject: 100479, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100117.nii.gz
# Looking for images in: /nfs/data/nii/data0/GNC/GNC_759/links/100742/30/3D_GRE_TRA_4/3D_GRE_TRA_W_COMPOSE*_s*.nii
# Subject: 100742, Files found: 1
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100861_0000.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100479.nii.gz  Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100692_0003.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100692/30/opportunistic-screening/seg.nii.gz
# Subject: 100692, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100692.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100861_0001.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100610_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100419_0000.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100861_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100610_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100419_0001.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100861_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100861/30/opportunistic-screening/seg.nii.gz
# Subject: 100861, Mask files found: 1
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100029_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100891_0000.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100861.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100419_0002.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100326_0000.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100610_0002.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100151_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100099_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100984_0000.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100029_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100891_0001.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100419_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100419/30/opportunistic-screening/seg.nii.gz
# Subject: 100419, Mask files found: 1
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100326_0001.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100610_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100610/30/opportunistic-screening/seg.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100151_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100029_0002.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100099_0001.nii.gz
# Subject: 100610, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100419.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100984_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100326_0002.nii.gz  Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100891_0002.nii.gz
#
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100610.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100151_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100029_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100029/30/opportunistic-screening/seg.nii.gz
# Subject: 100029, Mask files found: 1
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100099_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100326_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100326/30/opportunistic-screening/seg.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100984_0002.nii.gz
# Subject: 100326, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100891_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100891/30/opportunistic-screening/seg.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100724_0000.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100843_0000.nii.gz
# Subject: 100891, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100029.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100151_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100151/30/opportunistic-screening/seg.nii.gz
# Subject: 100151, Mask files found: 1  Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100665_0000.nii.gz
#
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100099_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100099/30/opportunistic-screening/seg.nii.gz
# Subject: 100099, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100326.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100891.nii.gz  Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100984_0003.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100984/30/opportunistic-screening/seg.nii.gz
# Subject: 100984, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100151.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100099.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100724_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100843_0001.nii.gz
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100665_0001.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100984.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100843_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100665_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100724_0002.nii.gz
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100742_0000.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100843_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100843/30/opportunistic-screening/seg.nii.gz
# Subject: 100843, Mask files found: 1
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100665_0003.nii.gz
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100665/30/opportunistic-screening/seg.nii.gz
# Subject: 100665, Mask files found: 1
#   Saved channel 0 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100644_0000.nii.gz  Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100724_0003.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100724/30/opportunistic-screening/seg.nii.gz
# Subject: 100724, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100665.nii.gz  Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100843.nii.gz
#
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100742_0001.nii.gz  Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100724.nii.gz
#
#   Saved channel 1 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100644_0001.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100742_0002.nii.gz
#   Saved channel 2 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100644_0002.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100742_0003.nii.gz
#   Saved channel 3 -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs/100644_0003.nii.gzLooking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100742/30/opportunistic-screening/seg.nii.gz
#
# Looking for masks in: /nfs/data/nii/data0/GNC/GNC_759/data/100644/30/opportunistic-screening/seg.nii.gz
# Subject: 100742, Mask files found: 1
# Subject: 100644, Mask files found: 1
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100742.nii.gz
#   Saved mask -> /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/100644.nii.gz

# %% [markdown]
# export nnUNet_raw="/nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw"
# export nnUNet_preprocessed="/nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_preprocessed"
# export nnUNet_results="/nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_results"
#
# nnUNetv2_plan_and_preprocess -np 16 -d 3 --verify_dataset_integrity -c 3d_fullres -pl nnUNetPlannerResEncM -gpu_memory_target 40 -overwrite_plans_name nnUNetResEncUNetPlans_40G
# nnUNetv2_train 3 3d_fullres -p nnUNetResEncUNetPlans_40G all
#
#
# nnUNetv2_predict \
#   -i /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/imagesTs \
#   -o /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/predsTs \
#   -d 3 \
#   -c 3d_fullres \
#   -f all \
#   -tr nnUNetTrainer \
#   -p nnUNetResEncUNetPlans_40G \
#   -chk checkpoint_best.pth
#
#
#
# python scripts/nnunet_patchwork_comp/eval.py \
#     --gt-pattern   /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs/{subject}.nii.gz \
#     --pred-pattern /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/predsTs/{subject}.nii.gz \
#     --subjects     /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset003_oppscreen_20_subjects/labelsTs \
#     --output       results/results_nnunet_50.json --no-nsd
