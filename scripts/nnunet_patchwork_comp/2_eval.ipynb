# %% [markdown]
# ## compute metrics
# # nnunet
# python scripts/nnunet_patchwork_comp/eval.py \
#     --gt-pattern   /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset002_oppscreen_all_2/labelsTs/{subject}.nii.gz \
#     --pred-pattern /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset002_oppscreen_all_2/predsTs_50/{subject}.nii.gz \
#     --subjects     /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/nnunet/nnUNet_raw/Dataset002_oppscreen_all_2/labelsTs \
#     --output       results/results_nnunet_50.json --no-nsd
#
# # Patchwork (our preds)
#   python scripts/nnunet_patchwork_comp/eval.py \
#     --gt-pattern   /nfs/data/nii/data1/camaret___whole_body_benchmark/{subject}/NII/{subject}_mask.nii.gz \
#     --pred-pattern /nfs/data/nii/data1/camaret___whole_body_benchmark/{subject}/NII/patchwork_pred_50.nii.gz \
#     --subjects     /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/data/oppscreen/splits_966.json --splits-key test \
#     --output       results/results_patchwork_50.json --no-nsd

# %% [markdown]
# ## final metrics
# # save plot
# python scripts/plot_results.py results/results_nnunet.json results/results_patchwork.json
#
# # interactive plot
# results/results_interactive.ipynb
#
# # learning curves patchwork
#   python scripts/nnunet_patchwork_comp/3_extract_learning_curve_patchwork.py \
#     /nfs/data/nii/data1/Analysis/camaret___whole_body_benchmark/ANALYSIS_ana001/patchwork_oppscreen_all \
#     -o results/learning_curves/patchwork_all
